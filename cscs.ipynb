# %%
# Data manipulation and analysis
import pandas as pd
import numpy as np
# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# Machine learning modules
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.feature_selection import SelectKBest, chi2, f_classif
# ML Models
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
# Evaluation metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Handle imbalanced data
from imblearn.over_sampling import SMOTE
# Model persistence
import joblib
# Set visualization style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# Load the dataset
df = pd.read_csv("abyu.csv")
# Display first 5 rows
print("First 5 rows of the dataset:")
df.head()
# Out:
# First 5 rows of the dataset:
#    sepal.length  sepal.width  petal.length  petal.width     species
# 0           7.6          3.0           6.6          2.1        abyu
# 1           7.3          2.9           6.3          1.8  abyu
# 2           7.2          3.6           6.1          2.5        abyu
# 3           7.2          3.0           5.8          1.6        abyu
# 4           7.4          2.8           6.1          1.9        abyu

# %%
# Get basic information about the dataset
print("Dataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  19 non-null     float64
#  1   sepal.width   19 non-null     float64
#  2   petal.length  19 non-null     float64
#  3   petal.width   19 non-null     float64
#  4   species       19 non-null     str
# dtypes: float64(4), str(1)
# memory usage: 892.0 bytes
